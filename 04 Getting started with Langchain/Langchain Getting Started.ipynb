# %%
# from langchain_ollama import ChatOllama
from dotenv import load_dotenv
from langchain_groq import ChatGroq

# %%
load_dotenv()

# base_url = "http://localhost:11434"
# model = 'qwen3:8b'


# llm = ChatOllama(
#     base_url=base_url,
#     model=model,
#     temperature=0.8,
#     num_predict = 256
# )

llm = ChatGroq(model="llama-3.1-8b-instant")

# %%
result = llm.invoke('new ways of working?').content

# %%
result
# Out:
# 'There are several new ways of working that have emerged in recent years, including:\n\n1. **Remote work**: With the advancement of technology, remote work has become increasingly popular. This allows employees to work from anywhere, at any time, as long as they have a stable internet connection.\n2. **Flexible scheduling**: Many companies are adopting flexible scheduling, which allows employees to choose their own hours or work from home. This can help improve work-life balance and increase productivity.\n3. **Job sharing**: Job sharing involves dividing a full-time job into two or more part-time positions. This can be a good option for employees who want to balance work and family responsibilities.\n4. **Gig economy**: The gig economy involves working on a freelance or contract basis, often through platforms such as Uber or TaskRabbit. This can provide flexibility and autonomy for workers, but may also lack job security and benefits.\n5. **Virtual teams**: Virtual teams involve working remotely, but with a team of people who are also working remotely. This can be a good option for companies that want to work with remote employees, or for employees who want to work with a team of people who share similar interests.\n6. **Autonomous work**: Autonomous work involves giving employees the freedom to work independently and make their own decisions. This can help increase motivation and productivity, but may also require more self-discipline and accountability.\n7. **Results-oriented work environment (ROWE)**: A ROWE is a work environment where employees are judged on their results, rather than their hours worked. This can help increase productivity and motivation, but may also require more accountability and self-discipline.\n8. **Holacracy**: Holacracy is a management system that involves breaking down traditional roles and hierarchies. This can help increase autonomy and flexibility, but may also require more communication and coordination among team members.\n9. **Time banking**: Time banking involves exchanging time and skills with others, rather than money. This can help build community and provide access to skills and resources that might not be available otherwise.\n10. **Wellness-centered work**: Wellness-centered work involves prioritizing employee well-being and creating a work environment that supports physical and mental health. This can help increase productivity and job satisfaction, but may also require more investment in employee wellness programs.\n\nThese are just a few examples of new ways of working. The future of work is likely to involve even more innovative and flexible approaches to work.\n\nAdditionally, some other trends and concepts that are emerging in the world of work include:\n\n- **The 4-day workweek**: Some companies are adopting a 4-day workweek, with the option to work from home on the fifth day.\n- **The use of AI and automation**: AI and automation are being used to automate routine tasks and free up human workers to focus on more complex and creative tasks.\n- **The rise of coworking spaces**: Coworking spaces provide a shared workspace for remote workers, freelancers, and entrepreneurs.\n- **The importance of work-life balance**: Many companies are prioritizing work-life balance, recognizing that employees need time to rest and recharge in order to be productive and engaged at work.\n\nThese are just a few examples, and the future of work is likely to involve even more innovative and flexible approaches to work.'
